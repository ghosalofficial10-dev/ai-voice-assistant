# %% [markdown]
# <a href="https://colab.research.google.com/github/ghosalofficial10-dev/ai-voice-assistant/blob/main/ai_voice_assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def kitty_chat(user_input):
    user_input = user_input.lower()

    if "hello" in user_input or "hi" in user_input:
        return "Hello! I’m Kitty 🐱. How can I help you?"

    elif "your name" in user_input:
        return "My name is Kitty, your AI assistant."

    elif "how are you" in user_input:
        return "I’m doing great! Thanks for asking 😊"

    elif "bye" in user_input:
        return "Goodbye! Talk to you soon 👋"

    else:
        return "I’m still learning. Can you ask something else?"

# %%
while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Kitty: Bye! 👋")
        break

    reply = kitty_chat(user)
    print("Kitty:", reply)
# Out:
# You: hi
# Kitty: Hello! I’m Kitty 🐱. How can I help you?
# You: how are you
# Kitty: I’m doing great! Thanks for asking 😊
# You: what is your name
# Kitty: My name is Kitty, your AI assistant.
# You: about your self
# Kitty: I’m still learning. Can you ask something else?
# You: exit
# Kitty: Bye! 👋
